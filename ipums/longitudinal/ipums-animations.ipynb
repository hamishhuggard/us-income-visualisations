# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from IPython.display import Image

# Assuming 'data' is your DataFrame
data = pd.read_csv('dat/data.csv')

# Grouping data by 'YEAR_1'
grouped_data = data.groupby('YEAR_1')['HHINCOME_2']

# Set up the figure for the animation
fig, ax = plt.subplots()

def animate(year):
    ax.clear()  # Clear the axis to update with new histogram
    incomes = grouped_data.get_group(year).dropna()  # Get incomes for the given year
    ax.hist(incomes, bins=50, color='blue', alpha=0.7)
    ax.set_title(f'Histogram of HHINCOME_2 for the Year {year}')
    ax.set_xlabel('HHINCOME_2 Value')
    ax.set_ylabel('Frequency')

# Unique years to iterate over
years = data['YEAR_1'].unique()

# Create the animation object
ani = animation.FuncAnimation(fig, animate, frames=years, repeat=False)

# Save the animation
ani.save('income_animation.gif')

Image(filename='animations/income_animation.gif')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from IPython.display import Image

# Assuming 'data' is your DataFrame
data = pd.read_csv('dat/data.csv')

# Grouping data by 'YEAR_1'
grouped_data = data.groupby('YEAR_1')['HHINCOME_2']

# Determine the bins based on the overall data
overall_bins = pd.cut(data['HHINCOME_2'], bins=50, retbins=True)[1]

# Set up the figure for the animation
fig, ax = plt.subplots()

def animate(year):
    ax.clear()  # Clear the axis to update with new histogram
    incomes = grouped_data.get_group(year).dropna()  # Get incomes for the given year
    ax.hist(incomes, bins=overall_bins, color='blue', alpha=0.7, density=True)
    ax.set_title(f'Histogram of HHINCOME_2 for the Year {year}')
    ax.set_xlabel('HHINCOME_2 Value')
    ax.set_ylabel('Percentage of Total')

# Unique years to iterate over
years = data['YEAR_1'].unique()

# Create the animation object
ani = animation.FuncAnimation(fig, animate, frames=years, repeat=False)

# Save the animation
ani.save('income_animation.gif')

Image(filename='income_animation.gif')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from IPython.display import Image

plt.style.use('ggplot')

# Assuming 'data' is your DataFrame
data = pd.read_csv('dat/data.csv')

# Truncate values in 'HHINCOME_2' over 500,000
data['HHINCOME_2'] = data['HHINCOME_2'].apply(lambda x: min(x, 500000))

# Grouping data by 'YEAR_1'
grouped_data = data.groupby('YEAR_1')['HHINCOME_2']

# Determine the bins based on the overall data
overall_bins = pd.cut(data['HHINCOME_2'], bins=50, retbins=True)[1]

# Set up the figure for the animation
fig, ax = plt.subplots()

def animate(year):
    ax.clear()  # Clear the axis to update with new histogram
    incomes = grouped_data.get_group(year).dropna()  # Get incomes for the given year
    ax.hist(incomes, bins=overall_bins, color='blue', alpha=0.7, density=True)
    ax.set_title(f'Histogram of HHINCOME_2 for the Year {year}')
    ax.set_xlabel('HHINCOME_2 Value')
    ax.set_ylabel('Percentage of Total')

# Unique years to iterate over
years = data['YEAR_1'].unique()

# Create the animation object
ani = animation.FuncAnimation(fig, animate, frames=years, repeat=False)

# Save the animation
ani.save('income_animation.gif')

Image(filename='income_animation.gif')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from IPython.display import Image

plt.style.use('ggplot')

# Assuming 'data' is your DataFrame
data = pd.read_csv('dat/data.csv')

# Truncate values in 'HHINCOME_2' over 500,000
data['HHINCOME_2'] = data['HHINCOME_2'].apply(lambda x: min(x, 300000))

# Grouping data by 'YEAR_1'
grouped_data = data.groupby('YEAR_1')['HHINCOME_2']

# Determine the bins based on the overall data
overall_bins = pd.cut(data['HHINCOME_2'], bins=50, retbins=True)[1]

# Set up the figure for the animation
fig, ax = plt.subplots()

def animate(year):
    ax.clear()  # Clear the axis to update with new histogram
    incomes = grouped_data.get_group(year).dropna()  # Get incomes for the given year
    ax.hist(incomes, bins=overall_bins, color='blue', alpha=0.7, density=True)
    ax.set_title(f'Histogram of HHINCOME_2 for the Year {year}')
    ax.set_xlabel('HHINCOME_2 Value')
    ax.set_ylabel('Percentage of Total')

# Unique years to iterate over
years = data['YEAR_1'].unique()

# Create the animation object
ani = animation.FuncAnimation(fig, animate, frames=years, repeat=False)

# Save the animation
ani.save('income_animation.gif')

Image(filename='income_animation.gif')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from IPython.display import Image

# Assuming 'data' is your DataFrame
data = pd.read_csv('dat/data.csv')

# Truncate values in 'HHINCOME_2' over 500,000
data['HHINCOME_2'] = data['HHINCOME_2'].apply(lambda x: min(x, 300000))

# Grouping data by 'YEAR_1'
grouped_data = data.groupby('YEAR_1')['HHINCOME_2']

# Determine the bins based on the overall data
overall_bins = pd.cut(data['HHINCOME_2'], bins=50, retbins=True)[1]

# Set up the figure for the animation
fig, ax = plt.subplots()

def animate(year):
    ax.clear()  # Clear the axis to update with new histogram
    incomes = grouped_data.get_group(year).dropna()  # Get incomes for the given year
    ax.hist(incomes, bins=overall_bins, color='blue', alpha=0.7, density=True)
    ax.set_title(f'Histogram of HHINCOME_2 for the Year {year}')
    ax.set_xlabel('HHINCOME_2 Value')
    ax.set_ylabel('Percentage of Total')
    ax.set_ylim(0, 3e-5)  # Set fixed y-axis limits

# Unique years to iterate over
years = data['YEAR_1'].unique()

# Create the animation object
ani = animation.FuncAnimation(fig, animate, frames=years, repeat=False)

# Save the animation
ani.save('income_animation.gif')

Image(filename='income_animation.gif')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from IPython.display import Image

# Assuming 'data' is your DataFrame
data = pd.read_csv('dat/data.csv')

# Truncate values in 'HHINCOME_2' over 500,000
data['HHINCOME_2'] = data['HHINCOME_2'].apply(lambda x: min(x, 350000))

# Grouping data by 'YEAR_1'
grouped_data = data.groupby('YEAR_1')['HHINCOME_2']

# Determine the bins based on the overall data
overall_bins = pd.cut(data['HHINCOME_2'], bins=50, retbins=True)[1]

# Set up the figure for the animation
fig, ax = plt.subplots()

def animate(year):
    ax.clear()  # Clear the axis to update with new histogram
    incomes = grouped_data.get_group(year).dropna()  # Get incomes for the given year
    ax.hist(incomes, bins=overall_bins, color='blue', alpha=0.7, density=True)
    ax.set_title(f'Household income in {year}')
    ax.set_xlabel('Household income (USD)')
    ax.set_ylabel('% of households')
    ax.set_ylim(0, 3e-5)  # Set fixed y-axis limits
    ax.set_xlim(0, 300000)  # Set fixed x-axis limits

# Unique years to iterate over
years = data['YEAR_1'].unique()

# Create the animation object
ani = animation.FuncAnimation(fig, animate, frames=years, repeat=False)

# Save the animation
ani.save('household_income.gif')

Image(filename='household_income.gif')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from IPython.display import Image

# Assuming 'data' is your DataFrame
data = pd.read_csv('dat/data.csv')

# Truncate values in 'HHINCOME_2' over 500,000
data['INCTOT_1'] = data['INCTOT_1'].apply(lambda x: min(x, 350000))

# Grouping data by 'YEAR_1'
grouped_data = data.groupby('YEAR_1')['INCTOT_1']

# Determine the bins based on the overall data
overall_bins = pd.cut(data['INCTOT_1'], bins=50, retbins=True)[1]

# Set up the figure for the animation
fig, ax = plt.subplots()

def animate(year):
    ax.clear()  # Clear the axis to update with new histogram
    incomes = grouped_data.get_group(year).dropna()  # Get incomes for the given year
    ax.hist(incomes, bins=overall_bins, color='blue', alpha=0.7, density=True)
    ax.set_title(f'Individual income in {year}')
    ax.set_xlabel('Individual income (USD)')
    ax.set_ylabel('% of households')
    ax.set_ylim(0, 6e-5)  # Set fixed y-axis limits
    ax.set_xlim(-20000, 300000)  # Set fixed x-axis limits

# Unique years to iterate over
years = data['YEAR_1'].unique()

# Create the animation object
ani = animation.FuncAnimation(fig, animate, frames=years, repeat=False)

# Save the animation
ani.save('individual_income.gif')

Image(filename='individual_income.gif')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import numpy as np
from IPython.display import Image

# Assuming 'data' is your DataFrame
data = pd.read_csv('dat/data.csv')

# Truncate values in 'HHINCOME_2' over 500,000
data['HHINCOME_2'] = data['HHINCOME_2'].apply(lambda x: min(x, 500000))

# Grouping data by 'YEAR_1'
grouped_data = data.groupby('YEAR_1')['HHINCOME_2']

# Determine the bins based on the overall data
overall_bins = pd.cut(data['HHINCOME_2'], bins=50, retbins=True)[1]

# Set up the figure for the animation
fig, ax = plt.subplots()

def animate(year):
    ax.clear()  # Clear the axis to update with new histogram
    incomes = grouped_data.get_group(year).dropna()  # Get incomes for the given year
    
    # Calculate histogram data
    counts, bins = np.histogram(incomes, bins=overall_bins)
    percentages = (counts / counts.sum()) * 100  # Convert counts to percentages
    
    # Create the histogram bars manually
    widths = np.diff(bins)
    ax.bar(bins[:-1], percentages, width=widths, color='blue', alpha=0.7)
    
    ax.set_title(f'Household income in {year}')
    ax.set_xlabel('Household income (USD)')
    ax.set_ylabel('% of households')
    ax.set_ylim(0, 35)  # Set fixed y-axis limits
    ax.set_xlim(0, 300000)  # Set fixed x-axis limits

# Unique years to iterate over
years = data['YEAR_1'].unique()

# Create the animation object
ani = animation.FuncAnimation(fig, animate, frames=years, repeat=False)

# Save the animation
ani.save('household_income.gif')

Image(filename='household_income.gif')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import numpy as np
from IPython.display import Image

plt.style.use('ggplot')

def create_income_animation(
        data, 
        income_col, 
        year_col, 
        truncate=None, 
        x_lim=None, 
        title="Household income", 
        xlabel="Household income (USD)", 
        ylabel="% of households", 
        save_as="income_animation.gif"
    ):
    """
    Creates and saves an animated histogram of income distribution over years.

    Parameters:
    data (pandas.DataFrame): The DataFrame containing the data.
    income_col (str): The name of the column representing income values.
    year_col (str): The name of the column representing year values.
    truncate (float, optional): A value to truncate the income values. Default is None.
    x_lim (tuple, optional): The limits for the x-axis as a tuple (min, max). Default is None.
    title (str, optional): The title of the plot. Default is "Household income".
    xlabel (str, optional): The label for the x-axis. Default is "Household income (USD)".
    ylabel (str, optional): The label for the y-axis. Default is "% of households".
    save_as (str, optional): The filename to save the animation. Default is "income_animation.gif".
    """
    if truncate is not None:
        data[income_col] = data[income_col].apply(lambda x: min(x, truncate))

    grouped_data = data.groupby(year_col)[income_col]
    overall_bins = pd.cut(data[income_col], bins=50, retbins=True)[1]

    fig, ax = plt.subplots()

    def animate(year):
        ax.clear()  # Clear the axis to update with new histogram
        incomes = grouped_data.get_group(year).dropna()
        
        # Calculate histogram data
        counts, bins = np.histogram(incomes, bins=overall_bins)
        percentages = (counts / counts.sum()) * 100
        
        # Create the histogram bars manually
        widths = np.diff(bins)
        ax.bar(bins[:-1], percentages, width=widths, color='blue', alpha=0.7)
        
        ax.set_title(f'{title} in {year}')
        ax.set_xlabel(xlabel)
        ax.set_ylabel(ylabel)
        ax.set_ylim(0, 100)  # Set fixed y-axis limits
        if x_lim is not None:
            ax.set_xlim(x_lim)

    years = data[year_col].unique()

    ani = animation.FuncAnimation(fig, animate, frames=years, repeat=False)
    ani.save(save_as)
    Image(filename=save_as)

# Usage
data = pd.read_csv('data/data.csv')
create_income_animation(
    data, 
    'HHINCOME_2', 
    'YEAR_1', 
    truncate=500000, 
    x_lim=(0, 300000), 
    save_as='household_income.gif'
)
Image(filename='household_income.gif')
